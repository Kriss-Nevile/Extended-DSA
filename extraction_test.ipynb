# %%
# !pip install -q sentence-transformers InstructorEmbedding

# %%
from google.colab import drive
import os

# Kết nối Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Thư mục gốc chứa project của bạn trên Drive
BASE_DIR = "/content/drive/MyDrive/Colab Notebooks/Extend_dsa"  # 🔁 sửa lại cho đúng

# Đường dẫn file data và thư mục lưu embedding
DATA_PATH = f"{BASE_DIR}/Data/merged_dataset.csv"
OUTPUT_DIR = f"{BASE_DIR}/Data/embeddings"
os.makedirs(OUTPUT_DIR, exist_ok=True)

print("DATA_PATH:", DATA_PATH)
print("OUTPUT_DIR:", OUTPUT_DIR)
# Out:
# DATA_PATH: /content/drive/MyDrive/Colab Notebooks/Extend_dsa/Data/merged_dataset.csv
# OUTPUT_DIR: /content/drive/MyDrive/Colab Notebooks/Extend_dsa/Data/embeddings

# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
import torch

from sentence_transformers import SentenceTransformer
from InstructorEmbedding import INSTRUCTOR



# Cấu hình 4 model
MODEL_CONFIGS = {
    "bge-base-en-v1.5": {
        "name": "BAAI/bge-base-en-v1.5",
        "type": "sentence_transformer",
        "prefix": None,          # không thêm prefix
    },
    "all-MiniLM-L6-v2": {
        "name": "sentence-transformers/all-MiniLM-L6-v2",
        "type": "sentence_transformer",
        "prefix": None,
    },
    "instructor-base": {
        "name": "hkunlp/instructor-base",
        "type": "instructor",
        "instruction": "Represent the sentence for semantic similarity.",
    },
    "e5-base-v2": {
        "name": "intfloat/e5-base-v2",
        "type": "sentence_transformer",
        # e5 thường dùng prefix "passage: " / "query: "
        "prefix": "passage: ",
    },
}

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Đọc data đã merge
df = pd.read_csv(DATA_PATH)

required_cols = ['text1', 'text2', 'is_duplicate']
missing = [c for c in required_cols if c not in df.columns]
if missing:
    raise ValueError("Thiếu các cột bắt buộc trong merged_dataset.csv: {}".format(missing))

# Chỉ giữ đúng 3 cột cần thiết
df = df[required_cols].copy()

# Bỏ NaN & chuỗi rỗng
df = df.dropna(subset=required_cols)
df['text1'] = df['text1'].astype(str).str.strip()
df['text2'] = df['text2'].astype(str).str.strip()
df = df[(df['text1'] != "") & (df['text2'] != "")]

# Đảm bảo label là int
df['is_duplicate'] = df['is_duplicate'].astype(int)

df = df.reset_index(drop=True)
print("Số mẫu sau khi lọc:", df.shape[0])
df.head()
# Out:
# Số mẫu sau khi lọc: 21626
#                                                text1  \
# 0  What are the best desktop configuration for a ...
# 1  How can I effectively market my app in a soft ...
# 2                         How do north Indians look?
# 3  How do I manage when you are speaking in group...
# 4                        Can a minor sue or be sued?
#
#                                                text2  is_duplicate
# 0  Which is the best laptop for game and graphic ...             0
# 1  What are good free ways to promote your Androi...             0
# 2                   Statergies of election in India?             0
# 3  How can you get over the feeling when your gan...             0
# 4                   Is it possible to sue Sea World?             0
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('text1').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('text2').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['is_duplicate']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'is_duplicate'}, axis=1)
#               .sort_values('is_duplicate', ascending=True))
#   xs = counted['is_duplicate']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_2.sort_values('is_duplicate', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('text1')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='text1', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('is_duplicate')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['is_duplicate']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'is_duplicate'}, axis=1)
#               .sort_values('is_duplicate', ascending=True))
#   xs = counted['is_duplicate']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_3.sort_values('is_duplicate', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('text2')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='text2', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('is_duplicate')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['text2'].value_counts()
#     for x_label, grp in _df_4.groupby('text1')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('text1')
# _ = plt.ylabel('text2')

# %%
def encode_sentence_transformer(model_name,
                                df,
                                output_dir,
                                prefix=None,
                                batch_size=64):
    print("\n=== Encode với model: {} ===".format(model_name))
    model = SentenceTransformer(model_name, device=device)

    if prefix:
        texts1 = (prefix + df['text1'].astype(str)).tolist()
        texts2 = (prefix + df['text2'].astype(str)).tolist()
    else:
        texts1 = df['text1'].tolist()
        texts2 = df['text2'].tolist()

    # Encode text1
    emb1 = model.encode(
        texts1,
        batch_size=batch_size,
        convert_to_numpy=True,
        show_progress_bar=True,
    )
    # Encode text2
    emb2 = model.encode(
        texts2,
        batch_size=batch_size,
        convert_to_numpy=True,
        show_progress_bar=True,
    )

    short_name = model_name.split("/")[-1]
    out_path = os.path.join(output_dir, "{}_pair_embeddings.npz".format(short_name))

    # Lưu cả 2 embedding + nhãn
    np.savez_compressed(
        out_path,
        text1_embeddings=emb1,
        text2_embeddings=emb2,
        is_duplicate=df['is_duplicate'].to_numpy(),
    )
    print("Đã lưu embeddings vào:", out_path)
    print("Shape text1:", emb1.shape, "| text2:", emb2.shape)

# %%
def encode_instructor(model_name,
                      instruction,
                      df,
                      output_dir,
                      batch_size=32):
    print("\n=== Encode với model INSTRUCTOR: {} ===".format(model_name))
    instructor_model = INSTRUCTOR(model_name)
    instructor_model.to(device)

    def batched_encode(pairs):
        all_embs = []
        for i in tqdm(range(0, len(pairs), batch_size)):
            batch = pairs[i:i + batch_size]
            emb = instructor_model.encode(batch)
            all_embs.append(np.array(emb))
        return np.vstack(all_embs)

    texts1 = df['text1'].tolist()
    texts2 = df['text2'].tolist()

    # INSTRUCTOR cần dạng [instruction, text]
    pairs1 = [[instruction, t] for t in texts1]
    pairs2 = [[instruction, t] for t in texts2]

    emb1 = batched_encode(pairs1)
    emb2 = batched_encode(pairs2)

    short_name = model_name.split("/")[-1]
    out_path = os.path.join(output_dir, "{}_pair_embeddings.npz".format(short_name))

    np.savez_compressed(
        out_path,
        text1_embeddings=emb1,
        text2_embeddings=emb2,
        is_duplicate=df['is_duplicate'].to_numpy(),
    )
    print("Đã lưu embeddings vào:", out_path)
    print("Shape text1:", emb1.shape, "| text2:", emb2.shape)

# %%
for short_name, cfg in MODEL_CONFIGS.items():
    mtype = cfg["type"]
    if mtype == "sentence_transformer":
        encode_sentence_transformer(
            model_name=cfg["name"],
            df=df,
            output_dir=OUTPUT_DIR,
            prefix=cfg.get("prefix"),
        )
    elif mtype == "instructor":
        encode_instructor(
            model_name=cfg["name"],
            instruction=cfg["instruction"],
            df=df,
            output_dir=OUTPUT_DIR,
        )
    else:
        raise ValueError("Unknown model type for {}: {}".format(short_name, mtype))
# Out:
# === Encode với model: BAAI/bge-base-en-v1.5 ===
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/777 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/338 [00:00<?, ?it/s]
# Batches:   0%|          | 0/338 [00:00<?, ?it/s]
# Đã lưu embeddings vào: /content/drive/MyDrive/Colab Notebooks/Extend_dsa/Data/embeddings/bge-base-en-v1.5_pair_embeddings.npz
# Shape text1: (21626, 768) | text2: (21626, 768)
#
# === Encode với model: sentence-transformers/all-MiniLM-L6-v2 ===
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/338 [00:00<?, ?it/s]
# Batches:   0%|          | 0/338 [00:00<?, ?it/s]
# Đã lưu embeddings vào: /content/drive/MyDrive/Colab Notebooks/Extend_dsa/Data/embeddings/all-MiniLM-L6-v2_pair_embeddings.npz
# Shape text1: (21626, 384) | text2: (21626, 384)
#
# === Encode với model INSTRUCTOR: hkunlp/instructor-base ===
# modules.json:   0%|          | 0.00/461 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name hkunlp/instructor-base. Creating a new one with mean pooling.
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/439M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/439M [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
#   0%|          | 0/676 [00:00<?, ?it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   0%|          | 1/676 [00:00<07:23,  1.52it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   0%|          | 2/676 [00:00<04:00,  2.80it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   0%|          | 3/676 [00:00<02:55,  3.84it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   1%|          | 4/676 [00:01<02:16,  4.91it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   1%|          | 6/676 [00:01<01:35,  7.00it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   1%|          | 7/676 [00:01<01:46,  6.31it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   1%|          | 8/676 [00:01<01:36,  6.90it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   1%|▏         | 9/676 [00:01<01:36,  6.94it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   1%|▏         | 10/676 [00:01<01:32,  7.22it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   2%|▏         | 11/676 [00:01<01:30,  7.33it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   2%|▏         | 13/676 [00:02<01:13,  9.04it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   2%|▏         | 15/676 [00:02<01:05, 10.07it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   3%|▎         | 17/676 [00:02<00:58, 11.32it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   3%|▎         | 19/676 [00:02<00:57, 11.41it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   3%|▎         | 21/676 [00:02<00:53, 12.18it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   3%|▎         | 23/676 [00:02<00:59, 11.01it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   4%|▎         | 25/676 [00:03<00:58, 11.21it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   4%|▍         | 27/676 [00:03<00:55, 11.78it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   4%|▍         | 29/676 [00:03<00:55, 11.62it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   5%|▍         | 31/676 [00:03<00:52, 12.25it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   5%|▍         | 33/676 [00:03<00:50, 12.82it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   5%|▌         | 35/676 [00:03<00:55, 11.65it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   5%|▌         | 37/676 [00:04<00:53, 11.96it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   6%|▌         | 39/676 [00:04<00:49, 12.77it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   6%|▌         | 41/676 [00:04<00:47, 13.44it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   6%|▋         | 43/676 [00:04<00:46, 13.71it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   7%|▋         | 45/676 [00:04<00:46, 13.69it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   7%|▋         | 47/676 [00:04<00:45, 13.82it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   7%|▋         | 49/676 [00:04<00:46, 13.44it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   8%|▊         | 51/676 [00:05<00:44, 14.07it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#   8%|▊         | 53/676 [00:05<00:44, 14.07it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#
/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  89%|████████▉ | 602/676 [00:51<00:06, 11.46it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  89%|████████▉ | 604/676 [00:51<00:06, 10.86it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  90%|████████▉ | 606/676 [00:51<00:06, 11.10it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  90%|████████▉ | 608/676 [00:51<00:06, 10.69it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  90%|█████████ | 610/676 [00:52<00:06, 10.98it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  91%|█████████ | 612/676 [00:52<00:06, 10.57it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  91%|█████████ | 614/676 [00:52<00:05, 11.23it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  91%|█████████ | 616/676 [00:52<00:05, 11.39it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  91%|█████████▏| 618/676 [00:52<00:05, 11.55it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  92%|█████████▏| 620/676 [00:52<00:04, 11.40it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  92%|█████████▏| 622/676 [00:53<00:04, 11.53it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  92%|█████████▏| 624/676 [00:53<00:04, 11.10it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  93%|█████████▎| 626/676 [00:53<00:04, 11.10it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  93%|█████████▎| 628/676 [00:53<00:04, 10.48it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  93%|█████████▎| 630/676 [00:53<00:04, 10.78it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  93%|█████████▎| 632/676 [00:54<00:03, 11.01it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  94%|█████████▍| 634/676 [00:54<00:03, 11.21it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  94%|█████████▍| 636/676 [00:54<00:03, 11.22it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  94%|█████████▍| 638/676 [00:54<00:03, 11.04it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  95%|█████████▍| 640/676 [00:54<00:03, 10.91it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  95%|█████████▍| 642/676 [00:55<00:03, 10.32it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  95%|█████████▌| 644/676 [00:55<00:02, 10.73it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  96%|█████████▌| 646/676 [00:55<00:02, 10.49it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  96%|█████████▌| 648/676 [00:55<00:02, 10.92it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  96%|█████████▌| 650/676 [00:55<00:02, 11.08it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  96%|█████████▋| 652/676 [00:55<00:02, 11.09it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  97%|█████████▋| 654/676 [00:56<00:02, 10.99it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  97%|█████████▋| 656/676 [00:56<00:01, 11.12it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  97%|█████████▋| 658/676 [00:56<00:01, 11.00it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  98%|█████████▊| 660/676 [00:56<00:01, 11.14it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  98%|█████████▊| 662/676 [00:56<00:01, 11.70it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  98%|█████████▊| 664/676 [00:56<00:01, 11.40it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  99%|█████████▊| 666/676 [00:57<00:00, 10.82it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  99%|█████████▉| 668/676 [00:57<00:00, 11.21it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  99%|█████████▉| 670/676 [00:57<00:00, 11.32it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
#  99%|█████████▉| 672/676 [00:57<00:00, 11.30it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# 100%|█████████▉| 674/676 [00:57<00:00, 11.49it/s]WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been deprecated, please use `SentenceTransformer.device` instead.
# 100%|██████████| 676/676 [00:58<00:00, 11.65it/s]
# Đã lưu embeddings vào: /content/drive/MyDrive/Colab Notebooks/Extend_dsa/Data/embeddings/instructor-base_pair_embeddings.npz
# Shape text1: (21626, 768) | text2: (21626, 768)
#
# === Encode với model: intfloat/e5-base-v2 ===
# modules.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/650 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# Batches:   0%|          | 0/338 [00:00<?, ?it/s]
# Batches:   0%|          | 0/338 [00:00<?, ?it/s]
# Đã lưu embeddings vào: /content/drive/MyDrive/Colab Notebooks/Extend_dsa/Data/embeddings/e5-base-v2_pair_embeddings.npz
# Shape text1: (21626, 768) | text2: (21626, 768)
